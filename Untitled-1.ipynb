# %% [markdown]
# efnn/
# ├── pyproject.toml
# ├── README.md
# ├── efnn/
# │   ├── __init__.py
# │   ├── config.py          # protocol constants (single source of truth)
# │   ├── utils.py           # deterministic seeding
# │   ├── fuzzy_ops.py       # Yager T-/S-norms (eqs. yager_tnorm / yager_snorm)
# │   ├── registry.py        # active-rule registry (warm-up, alive/active masks)
# │   ├── model.py           # Algorithm 1, gate-once invariant, surrogate
# │   ├── losses.py          # eq. total_objective and its components
# │   ├── learning.py        # replay buffer, online trainer, anchor manager
# │   ├── evolution.py       # rule birth / merge / prune protocol
# │   ├── drift.py           # W1 drift detector (regime breaks)
# │   ├── conformal.py       # Thm. fuzzy_prob_duality (i)/(ii)
# │   ├── certificates.py    # PAC-Bayes, Lipschitz, reliability horizon
# │   ├── market.py          # Heston + jumps + crash (day units)
# │   ├── features.py        # causal, market-observable features
# │   ├── trading.py         # position policy, execution, baselines
# │   ├── metrics.py         # Sharpe/Sortino/CAGR/MDD/Calmar + consistency audit
# │   ├── stats.py           # JKM, Holm, power analysis, paired t
# │   └── backtest.py        # end-to-end experiment runner
# ├── tests/
# │   ├── test_gate_once.py       # the paper's regression test
# │   ├── test_fuzzy_ops.py
# │   ├── test_conformal.py
# │   ├── test_pacbayes.py
# │   ├── test_model_math.py
# │   ├── test_metrics_stats.py
# │   └── test_evolution_market.py
# └── scripts/
#     └── run_backtest.py
